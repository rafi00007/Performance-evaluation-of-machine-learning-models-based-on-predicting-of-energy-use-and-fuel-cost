# %%
import pandas as pd
dataset= pd.read_csv(r"C:\Users\rafi\Desktop\master pro\NB7_by_LA.csv", encoding= 'unicode_escape', delimiter= ',')
print(dataset)
# Out:
#       Local Authority Code Local Authority  Quarter   Property Type  \
# 0                E07000223             Adur  2008/4           House
# 1                E07000223             Adur  2008/4            Flat
# 2                E07000223             Adur  2008/4  All properties
# 3                E07000223             Adur  2009/1           House
# 4                E07000223             Adur  2009/1        Bungalow
# ...                    ...              ...     ...             ...
# 71777            E06000014             York  2022/1      Maisonette
# 71778            E06000014             York  2022/1           House
# 71779            E06000014             York  2022/1            Flat
# 71780            E06000014             York  2022/1        Bungalow
# 71781            E06000014             York  2022/1  All properties
#
#       Number of Lodgements Total Floor Area (m2) Energy Use (kWh/m2 pa)  \
# 0                       16                   777                  1,917
# ...

# %%
All_columns=dataset.columns                                              
print(All_columns)
# Out:
# Index(['Local Authority Code', 'Local Authority ', 'Quarter', 'Property Type',
#        'Number of Lodgements', 'Total Floor Area (m2)',
#        'Energy Use (kWh/m2 pa)', 'Average Per Dwelling',
#        'Carbon Dioxide Emissions (tonnes pa)', 'Average Per Dwelling.1',
#        'Lighting Cost (£ pa)', 'Average Per Dwelling.2', 'Heating Cost (£ pa)',
#        'Average Per Dwelling.3', 'Hot Water Cost (£ pa)',
#        'Average Per Dwelling.4'],
#       dtype='object')

# %%
dataset.rename(columns = {'Average Per Dwelling':'EnergyUseAveragePerDwelling', 'Average Per Dwelling.1':'CarbonDioxideEmissionsAveragePerDwelling', 'Average Per Dwelling.2':'LightingCostAveragePerDwelling', 'Average Per Dwelling.3':'HeatingCostAveragePerDwelling',  'Average Per Dwelling.4':'HotWaterCostAveragePerDwelling' }, inplace = True)

# %%
del dataset['Local Authority Code']
del dataset['Energy Use (kWh/m2 pa)']
del dataset['Carbon Dioxide Emissions (tonnes pa)']
del dataset['Lighting Cost (£ pa)']
del dataset['Heating Cost (£ pa)']
del dataset['Hot Water Cost (£ pa)']

# %%
dataset
# Out:
#       Local Authority  Quarter   Property Type Number of Lodgements  \
# 0                 Adur  2008/4           House                   16
# 1                 Adur  2008/4            Flat                   16
# 2                 Adur  2008/4  All properties                   32
# 3                 Adur  2009/1           House                   16
# 4                 Adur  2009/1        Bungalow                    1
# ...                ...     ...             ...                  ...
# 71777             York  2022/1      Maisonette                    1
# 71778             York  2022/1           House                  111
# 71779             York  2022/1            Flat                   50
# 71780             York  2022/1        Bungalow                    4
# 71781             York  2022/1  All properties                  166
#
#       Total Floor Area (m2) EnergyUseAveragePerDwelling  \
# 0                       777                         119
# ...

# %%
dataset["Total Floor Area (m2)"]=dataset["Total Floor Area (m2)"].str.replace('[" ,]','')
# Out:
# C:\Users\rafi\AppData\Local\Temp\ipykernel_5212\259112534.py:1: FutureWarning: The default value of regex will change from True to False in a future version.
#   dataset["Total Floor Area (m2)"]=dataset["Total Floor Area (m2)"].str.replace('[" ,]','')

# %%
dataset["Total Floor Area (m2)"]=pd.to_numeric(dataset["Total Floor Area (m2)"], errors='coerce')
dataset["Number of Lodgements"]=pd.to_numeric(dataset["Number of Lodgements"], errors='coerce')
dataset["AverageFloorArea"] =round(dataset["Total Floor Area (m2)"].div(dataset["Number of Lodgements"]))

# %%
dataset
# Out:
#       Local Authority  Quarter   Property Type  Number of Lodgements  \
# 0                 Adur  2008/4           House                  16.0
# 1                 Adur  2008/4            Flat                  16.0
# 2                 Adur  2008/4  All properties                  32.0
# 3                 Adur  2009/1           House                  16.0
# 4                 Adur  2009/1        Bungalow                   1.0
# ...                ...     ...             ...                   ...
# 71777             York  2022/1      Maisonette                   1.0
# 71778             York  2022/1           House                 111.0
# 71779             York  2022/1            Flat                  50.0
# 71780             York  2022/1        Bungalow                   4.0
# 71781             York  2022/1  All properties                 166.0
#
#        Total Floor Area (m2) EnergyUseAveragePerDwelling  \
# 0                        777                         119
# ...

# %%
dataset.drop(dataset[(dataset['Property Type'] =="All properties")].index, inplace=True)

# %%
dataset
# Out:
#       Local Authority  Quarter Property Type  Number of Lodgements  \
# 0                 Adur  2008/4         House                  16.0
# 1                 Adur  2008/4          Flat                  16.0
# 3                 Adur  2009/1         House                  16.0
# 4                 Adur  2009/1      Bungalow                   1.0
# 6                 Adur  2009/2      Bungalow                   1.0
# ...                ...     ...           ...                   ...
# 71775             York  2021/4      Bungalow                   3.0
# 71777             York  2022/1    Maisonette                   1.0
# 71778             York  2022/1         House                 111.0
# 71779             York  2022/1          Flat                  50.0
# 71780             York  2022/1      Bungalow                   4.0
#
#        Total Floor Area (m2) EnergyUseAveragePerDwelling  \
# 0                        777                         119
# ...

# %%
dataset.groupby('Property Type').describe()
# Out:
#               Number of Lodgements                                          \
#                              count       mean         std  min   25%   50%
# Property Type
# Bungalow                   12177.0   5.756755    7.710310  1.0   1.0   3.0
# Flat                       16272.0  62.994100  102.852008  1.0  10.0  28.0
# House                      18141.0  79.469324   80.278526  1.0  26.0  55.0
# Maisonette                  6919.0   4.839861    8.693843  1.0   1.0   2.0
#
#                             Total Floor Area (m2)               ...  \
#                  75%    max                 count         mean  ...
# Property Type                                                   ...
# Bungalow         7.0   95.0               12177.0   520.281843  ...
# Flat            69.0  999.0               16307.0  3952.026492  ...
# House          105.0  908.0               18142.0  8843.598060  ...
# Maisonette       5.0  209.0                6919.0   386.454979  ...
#
# ...

# %%
dataset.loc[dataset['Property Type'] == 'Bungalow', 'Property Type'] = 1
dataset.loc[dataset['Property Type'] == 'Flat', 'Property Type'] = 2
dataset.loc[dataset['Property Type'] == 'House', 'Property Type'] = 3
dataset.loc[dataset['Property Type'] == 'Maisonette', 'Property Type'] = 4
dataset
# Out:
#       Local Authority  Quarter Property Type  Number of Lodgements  \
# 0                 Adur  2008/4             3                  16.0
# 1                 Adur  2008/4             2                  16.0
# 3                 Adur  2009/1             3                  16.0
# 4                 Adur  2009/1             1                   1.0
# 6                 Adur  2009/2             1                   1.0
# ...                ...     ...           ...                   ...
# 71775             York  2021/4             1                   3.0
# 71777             York  2022/1             4                   1.0
# 71778             York  2022/1             3                 111.0
# 71779             York  2022/1             2                  50.0
# 71780             York  2022/1             1                   4.0
#
#        Total Floor Area (m2) EnergyUseAveragePerDwelling  \
# 0                        777                         119
# ...

# %%
dataset.loc[dataset['Quarter'] == '2008/4', 'Quarter'] = 4
dataset.loc[dataset['Quarter'] == '2009/1', 'Quarter'] = 1
dataset.loc[dataset['Quarter'] == '2009/2', 'Quarter'] = 2
dataset.loc[dataset['Quarter'] == '2009/3', 'Quarter'] = 3
dataset.loc[dataset['Quarter'] == '2009/4', 'Quarter'] = 4
dataset.loc[dataset['Quarter'] == '2010/1', 'Quarter'] = 1
dataset.loc[dataset['Quarter'] == '2010/2', 'Quarter'] = 2
dataset.loc[dataset['Quarter'] == '2010/3', 'Quarter'] = 3
dataset.loc[dataset['Quarter'] == '2010/4', 'Quarter'] = 4
dataset.loc[dataset['Quarter'] == '2011/1', 'Quarter'] = 1
dataset.loc[dataset['Quarter'] == '2011/2', 'Quarter'] = 2
dataset.loc[dataset['Quarter'] == '2011/3', 'Quarter'] = 3
dataset.loc[dataset['Quarter'] == '2011/4', 'Quarter'] = 4
dataset.loc[dataset['Quarter'] == '2012/1', 'Quarter'] = 1
dataset.loc[dataset['Quarter'] == '2012/2', 'Quarter'] = 2
dataset.loc[dataset['Quarter'] == '2012/3', 'Quarter'] = 3
dataset.loc[dataset['Quarter'] == '2012/4', 'Quarter'] = 4
dataset.loc[dataset['Quarter'] == '2013/1', 'Quarter'] = 1
dataset.loc[dataset['Quarter'] == '2013/2', 'Quarter'] = 2
dataset.loc[dataset['Quarter'] == '2013/3', 'Quarter'] = 3
dataset.loc[dataset['Quarter'] == '2013/4', 'Quarter'] = 4
dataset.loc[dataset['Quarter'] == '2014/1', 'Quarter'] = 1
dataset.loc[dataset['Quarter'] == '2014/2', 'Quarter'] = 2
dataset.loc[dataset['Quarter'] == '2014/3', 'Quarter'] = 3
dataset.loc[dataset['Quarter'] == '2014/4', 'Quarter'] = 4
dataset.loc[dataset['Quarter'] == '2015/1', 'Quarter'] = 1
dataset.loc[dataset['Quarter'] == '2015/2', 'Quarter'] = 2
dataset.loc[dataset['Quarter'] == '2015/3', 'Quarter'] = 3
dataset.loc[dataset['Quarter'] == '2015/4', 'Quarter'] = 4
dataset.loc[dataset['Quarter'] == '2016/1', 'Quarter'] = 1
dataset.loc[dataset['Quarter'] == '2016/2', 'Quarter'] = 2
dataset.loc[dataset['Quarter'] == '2016/3', 'Quarter'] = 3
dataset.loc[dataset['Quarter'] == '2016/4', 'Quarter'] = 4
dataset.loc[dataset['Quarter'] == '2017/1', 'Quarter'] = 1
dataset.loc[dataset['Quarter'] == '2017/2', 'Quarter'] = 2
dataset.loc[dataset['Quarter'] == '2017/3', 'Quarter'] = 3
dataset.loc[dataset['Quarter'] == '2017/4', 'Quarter'] = 4
dataset.loc[dataset['Quarter'] == '2018/1', 'Quarter'] = 1
dataset.loc[dataset['Quarter'] == '2018/2', 'Quarter'] = 2
dataset.loc[dataset['Quarter'] == '2018/3', 'Quarter'] = 3
dataset.loc[dataset['Quarter'] == '2018/4', 'Quarter'] = 4
dataset.loc[dataset['Quarter'] == '2019/1', 'Quarter'] = 1
dataset.loc[dataset['Quarter'] == '2019/2', 'Quarter'] = 2
dataset.loc[dataset['Quarter'] == '2019/3', 'Quarter'] = 3
dataset.loc[dataset['Quarter'] == '2019/4', 'Quarter'] = 4
dataset.loc[dataset['Quarter'] == '2020/1', 'Quarter'] = 1
dataset.loc[dataset['Quarter'] == '2020/2', 'Quarter'] = 2
dataset.loc[dataset['Quarter'] == '2020/3', 'Quarter'] = 3
dataset.loc[dataset['Quarter'] == '2020/4', 'Quarter'] = 4
dataset.loc[dataset['Quarter'] == '2021/1', 'Quarter'] = 1
dataset.loc[dataset['Quarter'] == '2021/2', 'Quarter'] = 2
dataset.loc[dataset['Quarter'] == '2021/3', 'Quarter'] = 3
dataset.loc[dataset['Quarter'] == '2021/4', 'Quarter'] = 4
dataset.loc[dataset['Quarter'] == '2022/1', 'Quarter'] = 1

dataset
# Out:
#       Local Authority  Quarter Property Type  Number of Lodgements  \
# 0                 Adur       4             3                  16.0
# 1                 Adur       4             2                  16.0
# 3                 Adur       1             3                  16.0
# 4                 Adur       1             1                   1.0
# 6                 Adur       2             1                   1.0
# ...                ...     ...           ...                   ...
# 71775             York       4             1                   3.0
# 71777             York       1             4                   1.0
# 71778             York       1             3                 111.0
# 71779             York       1             2                  50.0
# 71780             York       1             1                   4.0
#
#        Total Floor Area (m2) EnergyUseAveragePerDwelling  \
# 0                        777                         119
# ...

# %%
del dataset['Number of Lodgements']
del dataset['Total Floor Area (m2)']
del dataset['CarbonDioxideEmissionsAveragePerDwelling']
del dataset['LightingCostAveragePerDwelling']
del dataset['HeatingCostAveragePerDwelling']
del dataset['HotWaterCostAveragePerDwelling']

# %%
dataset
# Out:
#       Local Authority  Quarter Property Type EnergyUseAveragePerDwelling  \
# 0                 Adur       4             3                         119
# 1                 Adur       4             2                         194
# 3                 Adur       1             3                         132
# 4                 Adur       1             1                         138
# 6                 Adur       2             1                         170
# ...                ...     ...           ...                         ...
# 71775             York       4             1                         126
# 71777             York       1             4                         126
# 71778             York       1             3                          85
# 71779             York       1             2                          98
# 71780             York       1             1                         106
#
#        AverageFloorArea
# 0                  49.0
# 1                  50.0
# ...

# %%
null_value=dataset.isna().sum()
print(null_value)
# Out:
# Local Authority                 0
# Quarter                         0
# Property Type                   0
# EnergyUseAveragePerDwelling     0
# AverageFloorArea               36
# dtype: int64

# %%
dataset.dropna(inplace= True)

# %%
null_value=dataset.isna().sum()
print(null_value)
# Out:
# Local Authority                0
# Quarter                        0
# Property Type                  0
# EnergyUseAveragePerDwelling    0
# AverageFloorArea               0
# dtype: int64

# %%
dataset["EnergyUseAveragePerDwelling"]=pd.to_numeric(dataset["EnergyUseAveragePerDwelling"], errors='coerce')
null_value=dataset.isna().sum()
print(null_value)
# Out:
# Local Authority                0
# Quarter                        0
# Property Type                  0
# EnergyUseAveragePerDwelling    4
# AverageFloorArea               0
# dtype: int64

# %%
import seaborn as sns
sns.boxplot(data=dataset["AverageFloorArea"])
# Out:
# <AxesSubplot:>

# %%
import numpy as np
import pandas as pd
mean1= pd.DataFrame.mean (dataset['AverageFloorArea'])
data_std=pd.DataFrame.std(dataset['AverageFloorArea'])
cut_off = data_std * 3
lower, upper = mean1 - cut_off, mean1 + cut_off
for x in dataset['AverageFloorArea']:
     if x <lower or x > upper:
            print(x)
print('lower bound:',lower)
print('upper bound:',upper)
# Out:
# 391.0
# 323.0
# 260.0
# 420.0
# 269.0
# 402.0
# 433.0
# 353.0
# 275.0
# 237.0
# 278.0
# 297.0
# 245.0
# 252.0
# 285.0
# 289.0
# 236.0
# 252.0
# 302.0
# 322.0
# 269.0
# 248.0
# 421.0
# 253.0
# 272.0
# 260.0
# 258.0
# 240.0
# 249.0
# 298.0
# 261.0
# 330.0
# 396.0
# 278.0
# 273.0
# 239.0
# 264.0
# 243.0
# 254.0
# 258.0
# 316.0
# 293.0
# 268.0
# 434.0
# 249.0
# 267.0
# 431.0
# 256.0
# 256.0
# 275.0
# 322.0
# 296.0
# 689.0
# 257.0
# 261.0
# 414.0
# 244.0
# 470.0
# 267.0
# 847.0
# 409.0
# 268.0
# 382.0
# 300.0
# 269.0
# 377.0
# 282.0
# 425.0
# 247.0
# 274.0
# 264.0
# 415.0
# 1125.0
# 1003.0
# 239.0
# 267.0
# 333.0
# 324.0
# 299.0
# 324.0
# 398.0
# 245.0
# 254.0
# 243.0
# 246.0
# 274.0
# 264.0
# 250.0
# 311.0
# 294.0
# 241.0
# 465.0
# 305.0
# 239.0
# 263.0
# 259.0
# 302.0
# 443.0
# 382.0
# 353.0
# 257.0
# 258.0
# 313.0
# 278.0
# 301.0
# 246.0
# 257.0
# 263.0
# 235.0
# 253.0
# 351.0
# 256.0
# 298.0
# 235.0
# 261.0
# 272.0
# 388.0
# 240.0
# 248.0
# 348.0
# 296.0
# 320.0
# 298.0
# 335.0
# ...

# %%
dataset.drop(dataset[(dataset['AverageFloorArea'] >234)].index, inplace=True)
dataset.drop(dataset[(dataset['AverageFloorArea'] <0)].index, inplace=True)

# %%
import seaborn as sns
sns.boxplot(data=dataset["AverageFloorArea"])
# Out:
# <AxesSubplot:>

# %%
import seaborn as sns
sns.boxplot(data=dataset["EnergyUseAveragePerDwelling"])
# Out:
# <AxesSubplot:>

# %%
import numpy as np
import pandas as pd
mean1= pd.DataFrame.mean (dataset['EnergyUseAveragePerDwelling'])
data_std=pd.DataFrame.std(dataset['EnergyUseAveragePerDwelling'])
cut_off = data_std * 3
lower, upper = mean1 - cut_off, mean1 + cut_off
for x in dataset['EnergyUseAveragePerDwelling']:
     if x <lower or x > upper:
            print(x)
print('lower bound:',lower)
print('upper bound:',upper)
# Out:
# 424.0
# 295.0
# 750.0
# 452.0
# 335.0
# 320.0
# 366.0
# 309.0
# 333.0
# 312.0
# 828.0
# 306.0
# 306.0
# 322.0
# 314.0
# 306.0
# 374.0
# 299.0
# 303.0
# 389.0
# 427.0
# 297.0
# 350.0
# 364.0
# 349.0
# 380.0
# 308.0
# 340.0
# 318.0
# 327.0
# 353.0
# 447.0
# 478.0
# 296.0
# 303.0
# 318.0
# 317.0
# 314.0
# 357.0
# 353.0
# 428.0
# 297.0
# 478.0
# 303.0
# 314.0
# 311.0
# 821.0
# 418.0
# 533.0
# 295.0
# 304.0
# 858.0
# 296.0
# 355.0
# 310.0
# 428.0
# 330.0
# 313.0
# 386.0
# 346.0
# 335.0
# 338.0
# 300.0
# 334.0
# 355.0
# 296.0
# 333.0
# 320.0
# 298.0
# 327.0
# 375.0
# 378.0
# 294.0
# 326.0
# 357.0
# 478.0
# 353.0
# 315.0
# 333.0
# 297.0
# 384.0
# 323.0
# 303.0
# 327.0
# 341.0
# 321.0
# 387.0
# 354.0
# 326.0
# 363.0
# 362.0
# 296.0
# 436.0
# 324.0
# 344.0
# 388.0
# 298.0
# 368.0
# 324.0
# 347.0
# 393.0
# 352.0
# 330.0
# 303.0
# 366.0
# 373.0
# 303.0
# 303.0
# 450.0
# 335.0
# 294.0
# 326.0
# 378.0
# 309.0
# 334.0
# 471.0
# 325.0
# 294.0
# 294.0
# 298.0
# 344.0
# 372.0
# 335.0
# 303.0
# 501.0
# ...

# %%
dataset.drop(dataset[(dataset['EnergyUseAveragePerDwelling'] >293)].index, inplace=True)
dataset.drop(dataset[(dataset['EnergyUseAveragePerDwelling'] <0)].index, inplace=True)

# %%
dataset1=dataset.groupby(['AverageFloorArea','Quarter','Property Type']).mean()
dataset1.to_csv(r"C:\Users\rafi\Desktop\master pro\NB7_by_LA1.csv")
dataset1
# Out:
#                                         EnergyUseAveragePerDwelling
# AverageFloorArea Quarter Property Type
# 0.0              1       1                               160.777778
#                          2                               142.000000
#                          3                               159.000000
#                          4                               161.350000
#                  2       1                               200.000000
# ...                                                             ...
# 234.0            2       3                                78.000000
#                  3       1                               169.000000
#                          3                                87.000000
#                  4       1                                82.666667
#                          3                                87.000000
#
# [2753 rows x 1 columns]
