# %%
import pandas as pd
dataset= pd.read_csv(r"C:\Users\rafi\Desktop\master pro\EB7_by_LA.csv", encoding= 'unicode_escape', delimiter= ',')
print(dataset)
# Out:
# C:\Users\rafi\AppData\Local\Temp\ipykernel_8276\2267689716.py:2: DtypeWarning: Columns (16) have mixed types. Specify dtype option on import or set low_memory=False.
#   dataset= pd.read_csv(r"C:\Users\rafi\Desktop\master pro\EB7_by_LA.csv", encoding= 'unicode_escape', delimiter= ',')
#       Local Authority Code Local Authority Year/Quarter   Property Type  \
# 0                E07000223            Adur       2008/4      Maisonette
# 1                E07000223            Adur       2008/4           House
# 2                E07000223            Adur       2008/4            Flat
# 3                E07000223            Adur       2008/4        Bungalow
# 4                E07000223            Adur       2008/4  All properties
# ...                    ...             ...          ...             ...
# 92698            E06000014            York       2022/1      Maisonette
# 92699            E06000014            York       2022/1           House
# ...

# %%
All_columns=dataset.columns                                              
print(All_columns)
# Out:
# Index(['Local Authority Code', 'Local Authority', 'Year/Quarter',
#        'Property Type', 'Number of Lodgements', 'Total Floor Area (m2)',
#        'No Habitable Rooms (RdSAP Only)', 'Energy Use (kWh/m2 pa)',
#        'Average Per Dwelling', 'Carbon Dioxide Emissions (tonnes pa)',
#        'Average Per Dwelling.1', 'Lighting Cost (£ pa)',
#        'Average Per Dwelling.2', 'Heating Cost (£ pa)',
#        'Average Per Dwelling.3', 'Hot Water Cost (£ pa)',
#        'Average Per Dwelling.4'],
#       dtype='object')

# %%
dataset.rename(columns = {'Average Per Dwelling':'EnergyUseAveragePerDwelling', 'Average Per Dwelling.1':'CarbonDioxideEmissionsAveragePerDwelling', 'Average Per Dwelling.2':'LightingCostAveragePerDwelling', 'Average Per Dwelling.3':'HeatingCostAveragePerDwelling',  'Average Per Dwelling.4':'HotWaterCostAveragePerDwelling' }, inplace = True)

# %%
del dataset['Local Authority Code']
del dataset['No Habitable Rooms (RdSAP Only)']
del dataset['Energy Use (kWh/m2 pa)']
del dataset['Carbon Dioxide Emissions (tonnes pa)']
del dataset['Lighting Cost (£ pa)']
del dataset['Heating Cost (£ pa)']
del dataset['Hot Water Cost (£ pa)']

# %%
dataset
# Out:
#       Local Authority Year/Quarter   Property Type Number of Lodgements  \
# 0                Adur       2008/4      Maisonette                   10
# 1                Adur       2008/4           House                  158
# 2                Adur       2008/4            Flat                  237
# 3                Adur       2008/4        Bungalow                   86
# 4                Adur       2008/4  All properties                  491
# ...               ...          ...             ...                  ...
# 92698            York       2022/1      Maisonette                   16
# 92699            York       2022/1           House                  677
# 92700            York       2022/1            Flat                  289
# 92701            York       2022/1        Bungalow                  106
# 92702            York       2022/1  All properties                1,088
#
#       Total Floor Area (m2) EnergyUseAveragePerDwelling  \
# ...

# %%
dataset["Total Floor Area (m2)"]=dataset["Total Floor Area (m2)"].str.replace('[" ,]','')
# Out:
# C:\Users\rafi\AppData\Local\Temp\ipykernel_8276\259112534.py:1: FutureWarning: The default value of regex will change from True to False in a future version.
#   dataset["Total Floor Area (m2)"]=dataset["Total Floor Area (m2)"].str.replace('[" ,]','')

# %%
dataset["Total Floor Area (m2)"]=pd.to_numeric(dataset["Total Floor Area (m2)"], errors='coerce')
dataset["Number of Lodgements"]=pd.to_numeric(dataset["Number of Lodgements"], errors='coerce')
dataset["AverageFloorArea"] =round(dataset["Total Floor Area (m2)"].div(dataset["Number of Lodgements"]))

# %%
dataset
# Out:
#       Local Authority Year/Quarter   Property Type  Number of Lodgements  \
# 0                Adur       2008/4      Maisonette                  10.0
# 1                Adur       2008/4           House                 158.0
# 2                Adur       2008/4            Flat                 237.0
# 3                Adur       2008/4        Bungalow                  86.0
# 4                Adur       2008/4  All properties                 491.0
# ...               ...          ...             ...                   ...
# 92698            York       2022/1      Maisonette                  16.0
# 92699            York       2022/1           House                 677.0
# 92700            York       2022/1            Flat                 289.0
# 92701            York       2022/1        Bungalow                 106.0
# 92702            York       2022/1  All properties                   NaN
#
#        Total Floor Area (m2) EnergyUseAveragePerDwelling  \
# ...

# %%
dataset.drop(dataset[(dataset['Property Type'] =="All properties")].index, inplace=True)

# %%
dataset
# Out:
#       Local Authority Year/Quarter Property Type  Number of Lodgements  \
# 0                Adur       2008/4    Maisonette                  10.0
# 1                Adur       2008/4         House                 158.0
# 2                Adur       2008/4          Flat                 237.0
# 3                Adur       2008/4      Bungalow                  86.0
# 5                Adur       2009/1    Maisonette                  10.0
# ...               ...          ...           ...                   ...
# 92696            York       2021/4      Bungalow                 106.0
# 92698            York       2022/1    Maisonette                  16.0
# 92699            York       2022/1         House                 677.0
# 92700            York       2022/1          Flat                 289.0
# 92701            York       2022/1      Bungalow                 106.0
#
#        Total Floor Area (m2) EnergyUseAveragePerDwelling  \
# ...

# %%
dataset.groupby('Property Type').describe()
# Out:
#               Number of Lodgements                                             \
#                              count        mean         std  min    25%    50%
# Property Type
# Bungalow                   18135.0  100.230218   95.305559  1.0   43.0   75.0
# Flat                       17168.0  211.283143  199.384891  1.0   73.0  141.0
# House                      15493.0  481.721293  207.251301  1.0  324.0  454.0
# Maisonette                 17852.0   29.394017   46.568677  1.0    6.0   14.0
# Park home                   1787.0    5.019026   11.945550  1.0    1.0    1.0
#
#                             Total Floor Area (m2)                ...  \
#                  75%    max                 count          mean  ...
# Property Type                                                    ...
# Bungalow       124.0  983.0               18161.0   8327.455592  ...
# Flat           278.0  999.0               18301.0  16446.566854  ...
# ...

# %%
dataset.loc[dataset['Property Type'] == 'Bungalow', 'Property Type'] = 1
dataset.loc[dataset['Property Type'] == 'Flat', 'Property Type'] = 2
dataset.loc[dataset['Property Type'] == 'House', 'Property Type'] = 3
dataset.loc[dataset['Property Type'] == 'Maisonette', 'Property Type'] = 4
dataset.loc[dataset['Property Type'] == 'Park home', 'Property Type'] = 5
dataset
# Out:
#       Local Authority Year/Quarter Property Type  Number of Lodgements  \
# 0                Adur       2008/4             4                  10.0
# 1                Adur       2008/4             3                 158.0
# 2                Adur       2008/4             2                 237.0
# 3                Adur       2008/4             1                  86.0
# 5                Adur       2009/1             4                  10.0
# ...               ...          ...           ...                   ...
# 92696            York       2021/4             1                 106.0
# 92698            York       2022/1             4                  16.0
# 92699            York       2022/1             3                 677.0
# 92700            York       2022/1             2                 289.0
# 92701            York       2022/1             1                 106.0
#
#        Total Floor Area (m2) EnergyUseAveragePerDwelling  \
# ...

# %%
dataset.loc[dataset['Year/Quarter'] == '2008/4', 'Year/Quarter'] = 4
dataset.loc[dataset['Year/Quarter'] == '2009/1', 'Year/Quarter'] = 1
dataset.loc[dataset['Year/Quarter'] == '2009/2', 'Year/Quarter'] = 2
dataset.loc[dataset['Year/Quarter'] == '2009/3', 'Year/Quarter'] = 3
dataset.loc[dataset['Year/Quarter'] == '2009/4', 'Year/Quarter'] = 4
dataset.loc[dataset['Year/Quarter'] == '2010/1', 'Year/Quarter'] = 1
dataset.loc[dataset['Year/Quarter'] == '2010/2', 'Year/Quarter'] = 2
dataset.loc[dataset['Year/Quarter'] == '2010/3', 'Year/Quarter'] = 3
dataset.loc[dataset['Year/Quarter'] == '2010/4', 'Year/Quarter'] = 4
dataset.loc[dataset['Year/Quarter'] == '2011/1', 'Year/Quarter'] = 1
dataset.loc[dataset['Year/Quarter'] == '2011/2', 'Year/Quarter'] = 2
dataset.loc[dataset['Year/Quarter'] == '2011/3', 'Year/Quarter'] = 3
dataset.loc[dataset['Year/Quarter'] == '2011/4', 'Year/Quarter'] = 4
dataset.loc[dataset['Year/Quarter'] == '2012/1', 'Year/Quarter'] = 1
dataset.loc[dataset['Year/Quarter'] == '2012/2', 'Year/Quarter'] = 2
dataset.loc[dataset['Year/Quarter'] == '2012/3', 'Year/Quarter'] = 3
dataset.loc[dataset['Year/Quarter'] == '2012/4', 'Year/Quarter'] = 4
dataset.loc[dataset['Year/Quarter'] == '2013/1', 'Year/Quarter'] = 1
dataset.loc[dataset['Year/Quarter'] == '2013/2', 'Year/Quarter'] = 2
dataset.loc[dataset['Year/Quarter'] == '2013/3', 'Year/Quarter'] = 3
dataset.loc[dataset['Year/Quarter'] == '2013/4', 'Year/Quarter'] = 4
dataset.loc[dataset['Year/Quarter'] == '2014/1', 'Year/Quarter'] = 1
dataset.loc[dataset['Year/Quarter'] == '2014/2', 'Year/Quarter'] = 2
dataset.loc[dataset['Year/Quarter'] == '2014/3', 'Year/Quarter'] = 3
dataset.loc[dataset['Year/Quarter'] == '2014/4', 'Year/Quarter'] = 4
dataset.loc[dataset['Year/Quarter'] == '2015/1', 'Year/Quarter'] = 1
dataset.loc[dataset['Year/Quarter'] == '2015/2', 'Year/Quarter'] = 2
dataset.loc[dataset['Year/Quarter'] == '2015/3', 'Year/Quarter'] = 3
dataset.loc[dataset['Year/Quarter'] == '2015/4', 'Year/Quarter'] = 4
dataset.loc[dataset['Year/Quarter'] == '2016/1', 'Year/Quarter'] = 1
dataset.loc[dataset['Year/Quarter'] == '2016/2', 'Year/Quarter'] = 2
dataset.loc[dataset['Year/Quarter'] == '2016/3', 'Year/Quarter'] = 3
dataset.loc[dataset['Year/Quarter'] == '2016/4', 'Year/Quarter'] = 4
dataset.loc[dataset['Year/Quarter'] == '2017/1', 'Year/Quarter'] = 1
dataset.loc[dataset['Year/Quarter'] == '2017/2', 'Year/Quarter'] = 2
dataset.loc[dataset['Year/Quarter'] == '2017/3', 'Year/Quarter'] = 3
dataset.loc[dataset['Year/Quarter'] == '2017/4', 'Year/Quarter'] = 4
dataset.loc[dataset['Year/Quarter'] == '2018/1', 'Year/Quarter'] = 1
dataset.loc[dataset['Year/Quarter'] == '2018/2', 'Year/Quarter'] = 2
dataset.loc[dataset['Year/Quarter'] == '2018/3', 'Year/Quarter'] = 3
dataset.loc[dataset['Year/Quarter'] == '2018/4', 'Year/Quarter'] = 4
dataset.loc[dataset['Year/Quarter'] == '2019/1', 'Year/Quarter'] = 1
dataset.loc[dataset['Year/Quarter'] == '2019/2', 'Year/Quarter'] = 2
dataset.loc[dataset['Year/Quarter'] == '2019/3', 'Year/Quarter'] = 3
dataset.loc[dataset['Year/Quarter'] == '2019/4', 'Year/Quarter'] = 4
dataset.loc[dataset['Year/Quarter'] == '2020/1', 'Year/Quarter'] = 1
dataset.loc[dataset['Year/Quarter'] == '2020/2', 'Year/Quarter'] = 2
dataset.loc[dataset['Year/Quarter'] == '2020/3', 'Year/Quarter'] = 3
dataset.loc[dataset['Year/Quarter'] == '2020/4', 'Year/Quarter'] = 4
dataset.loc[dataset['Year/Quarter'] == '2021/1', 'Year/Quarter'] = 1
dataset.loc[dataset['Year/Quarter'] == '2021/2', 'Year/Quarter'] = 2
dataset.loc[dataset['Year/Quarter'] == '2021/3', 'Year/Quarter'] = 3
dataset.loc[dataset['Year/Quarter'] == '2021/4', 'Year/Quarter'] = 4
dataset.loc[dataset['Year/Quarter'] == '2022/1', 'Year/Quarter'] = 1

dataset
# Out:
#       Local Authority Year/Quarter Property Type  Number of Lodgements  \
# 0                Adur            4             4                  10.0
# 1                Adur            4             3                 158.0
# 2                Adur            4             2                 237.0
# 3                Adur            4             1                  86.0
# 5                Adur            1             4                  10.0
# ...               ...          ...           ...                   ...
# 92696            York            4             1                 106.0
# 92698            York            1             4                  16.0
# 92699            York            1             3                 677.0
# 92700            York            1             2                 289.0
# 92701            York            1             1                 106.0
#
#        Total Floor Area (m2) EnergyUseAveragePerDwelling  \
# ...

# %%
del dataset['Number of Lodgements']
del dataset['Total Floor Area (m2)']
del dataset['CarbonDioxideEmissionsAveragePerDwelling']
del dataset['LightingCostAveragePerDwelling']
del dataset['HeatingCostAveragePerDwelling']
del dataset['HotWaterCostAveragePerDwelling']

# %%
dataset
# Out:
#       Local Authority Year/Quarter Property Type EnergyUseAveragePerDwelling  \
# 0                Adur            4             4                         436
# 1                Adur            4             3                         306
# 2                Adur            4             2                         368
# 3                Adur            4             1                         384
# 5                Adur            1             4                         430
# ...               ...          ...           ...                         ...
# 92696            York            4             1                         285
# 92698            York            1             4                         250
# 92699            York            1             3                         255
# 92700            York            1             2                         282
# 92701            York            1             1                         281
#
#        AverageFloorArea
# ...

# %%
null_value=dataset.isna().sum()
print(null_value)
# Out:
# Local Authority                   0
# Year/Quarter                      0
# Property Type                     0
# EnergyUseAveragePerDwelling       0
# AverageFloorArea               3953
# dtype: int64

# %%
dataset.dropna(inplace= True)

# %%
null_value=dataset.isna().sum()
print(null_value)
# Out:
# Local Authority                0
# Year/Quarter                   0
# Property Type                  0
# EnergyUseAveragePerDwelling    0
# AverageFloorArea               0
# dtype: int64

# %%
dataset["EnergyUseAveragePerDwelling"]=pd.to_numeric(dataset["EnergyUseAveragePerDwelling"], errors='coerce')
null_value=dataset.isna().sum()
print(null_value)
dataset.dropna(inplace= True)
null_value=dataset.isna().sum()
print(null_value)
# Out:
# Local Authority                 0
# Year/Quarter                    0
# Property Type                   0
# EnergyUseAveragePerDwelling    31
# AverageFloorArea                0
# dtype: int64
# Local Authority                0
# Year/Quarter                   0
# Property Type                  0
# EnergyUseAveragePerDwelling    0
# AverageFloorArea               0
# dtype: int64

# %%
import seaborn as sns
sns.boxplot(data=dataset["AverageFloorArea"])
# Out:
# <AxesSubplot:>

# %%
import numpy as np
import pandas as pd
mean1= pd.DataFrame.mean (dataset['AverageFloorArea'])
data_std=pd.DataFrame.std(dataset['AverageFloorArea'])
cut_off = data_std * 3
lower, upper = mean1 - cut_off, mean1 + cut_off
for x in dataset['AverageFloorArea']:
     if x <lower or x > upper:
            print(x)
print('lower bound:',lower)
print('upper bound:',upper)
# Out:
# 263.0
# 235.0
# 176.0
# 267.0
# 278.0
# 159.0
# 169.0
# 168.0
# 182.0
# 176.0
# 176.0
# 173.0
# 172.0
# 170.0
# 166.0
# 165.0
# 204.0
# 185.0
# 167.0
# 174.0
# 171.0
# 172.0
# 177.0
# 182.0
# 194.0
# 183.0
# 170.0
# 184.0
# 202.0
# 179.0
# 181.0
# 182.0
# 175.0
# 173.0
# 179.0
# 222.0
# 167.0
# 174.0
# 177.0
# 186.0
# 160.0
# 194.0
# 177.0
# 158.0
# 164.0
# 163.0
# 199.0
# 169.0
# 193.0
# 184.0
# 174.0
# 172.0
# 170.0
# 164.0
# 181.0
# 172.0
# 276.0
# 374.0
# 216.0
# 185.0
# 210.0
# 188.0
# 193.0
# 169.0
# 337.0
# 161.0
# 182.0
# 217.0
# 180.0
# 212.0
# 229.0
# 176.0
# 224.0
# 172.0
# 184.0
# 237.0
# 372.0
# 3702.0
# 177.0
# 180.0
# 195.0
# 163.0
# 160.0
# 158.0
# 166.0
# 159.0
# 158.0
# 160.0
# 162.0
# 161.0
# 158.0
# 162.0
# 189.0
# 207.0
# 165.0
# 177.0
# 169.0
# 207.0
# 203.0
# 255.0
# 166.0
# 215.0
# 168.0
# 173.0
# 163.0
# 211.0
# 191.0
# 173.0
# 192.0
# 200.0
# 192.0
# 185.0
# 206.0
# 190.0
# 167.0
# 204.0
# 180.0
# 183.0
# 208.0
# 225.0
# 206.0
# 247.0
# 218.0
# 219.0
# ...

# %%
dataset.drop(dataset[(dataset['AverageFloorArea'] >157)].index, inplace=True)
dataset.drop(dataset[(dataset['AverageFloorArea'] <0)].index, inplace=True)

# %%
import seaborn as sns
sns.boxplot(data=dataset["EnergyUseAveragePerDwelling"])
# Out:
# <AxesSubplot:>

# %%
import numpy as np
import pandas as pd
mean1= pd.DataFrame.mean (dataset['EnergyUseAveragePerDwelling'])
data_std=pd.DataFrame.std(dataset['EnergyUseAveragePerDwelling'])
cut_off = data_std * 3
lower, upper = mean1 - cut_off, mean1 + cut_off
for x in dataset['EnergyUseAveragePerDwelling']:
     if x <lower or x > upper:
            print(x)
print('lower bound:',lower)
print('upper bound:',upper)
# Out:
# 530.0
# 582.0
# 501.0
# 510.0
# 521.0
# 500.0
# 500.0
# 513.0
# 710.0
# 585.0
# 565.0
# 630.0
# 591.0
# 561.0
# 574.0
# 521.0
# 531.0
# 490.0
# 516.0
# 540.0
# 708.0
# 776.0
# 813.0
# 532.0
# 583.0
# 516.0
# 489.0
# 666.0
# 502.0
# 488.0
# 488.0
# 528.0
# 726.0
# 513.0
# 517.0
# 627.0
# 642.0
# 791.0
# 502.0
# 497.0
# 522.0
# 501.0
# 497.0
# 621.0
# 607.0
# 516.0
# 490.0
# 489.0
# 530.0
# 520.0
# 643.0
# 513.0
# 489.0
# 644.0
# 793.0
# 727.0
# 523.0
# 741.0
# 570.0
# 528.0
# 497.0
# 507.0
# 535.0
# 506.0
# 602.0
# 530.0
# 554.0
# 528.0
# 727.0
# 622.0
# 501.0
# 549.0
# 643.0
# 575.0
# 538.0
# 519.0
# 539.0
# 490.0
# 679.0
# 498.0
# 557.0
# 516.0
# 692.0
# 496.0
# 574.0
# 773.0
# 692.0
# 595.0
# 546.0
# 498.0
# 707.0
# 553.0
# 713.0
# 653.0
# 552.0
# 568.0
# 600.0
# 551.0
# 536.0
# 492.0
# 521.0
# 506.0
# 715.0
# 602.0
# 510.0
# 511.0
# 504.0
# 615.0
# 872.0
# 534.0
# 497.0
# 519.0
# 585.0
# 602.0
# 886.0
# 529.0
# 898.0
# 829.0
# 496.0
# 534.0
# 649.0
# 613.0
# 508.0
# 875.0
# 560.0
# ...

# %%
dataset.drop(dataset[(dataset['EnergyUseAveragePerDwelling'] >487)].index, inplace=True)
dataset.drop(dataset[(dataset['EnergyUseAveragePerDwelling'] <110)].index, inplace=True)

# %%
dataset1=dataset.groupby(['AverageFloorArea','Year/Quarter','Property Type']).mean()
dataset1.to_csv(r"C:\Users\rafi\Desktop\master pro\EB7_by_LA1.csv")
dataset1
# Out:
#                                              EnergyUseAveragePerDwelling
# AverageFloorArea Year/Quarter Property Type
# 14.0             1            5                                    356.0
#                  4            1                                    468.0
# 19.0             1            4                                    375.0
# 20.0             1            1                                    464.5
#                               2                                    366.0
# ...                                                                  ...
# 156.0            3            3                                    253.0
#                               4                                    289.0
#                  4            4                                    220.0
# 157.0            2            3                                    316.0
#                  4            3                                    254.5
#
# [1626 rows x 1 columns]
